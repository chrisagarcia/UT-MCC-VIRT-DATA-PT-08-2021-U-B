# %%
from key import api_key
import requests

# %%
r = requests.get("https://api.nytimes.com/svc/books/v3/lists/overview.json", params={
    "api-key": api_key,
    "published_date": "2013-05-22"
})

# %%
best_sellers_data = r.json()

# %%
best_sellers_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'num_results': 105,
#  'results': {'bestsellers_date': '2013-05-11',
#   'published_date': '2013-05-26',
#   'published_date_description': '',
#   'previous_published_date': '2013-05-19',
#   'next_published_date': '2013-06-02',
#   'lists': [{'list_id': 704,
#     'list_name': 'Combined Print and E-Book Fiction',
#     'list_name_encoded': 'combined-print-and-e-book-fiction',
#     'display_name': 'Combined Print & E-Book Fiction',
#     'updated': 'WEEKLY',
#     'list_image': 'https://storage.googleapis.com/du-prd/books/images/9781937007881.jpg',
#     'list_image_width': 128,
#     'list_image_height': 193,
#     'books': [{'age_group': '',
#       'amazon_product_url': 'http://www.amazon.com/Dead-Ever-After-Sookie-Stackhouse/dp/193700788X?tag=NYTBSREV-20',
#       'article_chapter_link': '',
#       'author': 'Charlaine Harris',
# ...

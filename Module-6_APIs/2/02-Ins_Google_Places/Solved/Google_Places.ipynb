# %%
# Dependencies
import requests
import json
from pprint import pprint

# Google developer API key
from config import gkey

# %%
# geocoordinates
target_coordinates = "43.6187102, -116.2146068"
target_search = "Chinese"
target_radius = 8000
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
pprint(places_data)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECqYq_pZnGtcfGJ01dsyptJhvfiMQjjugcghka9ibzRic1FFpFeW0Cot-SDv26izA4qRJqJn34lHwSujuCLY6av4lDGDLw8EXhKWytAu6wD-lMYUhNllsun9ZxleMyjfQYowYXFpKf13VHKZ42LhZFnR92yoj9059xYp8Y8j1gJLqSkGXLJLH9mWzfhEI13MvD7Mjg8W-91dqC7JLh_FHN8puVTAEWZV5HDUQdKnxRaW4M6y4Gh0jDNooqTdefArNSfEZXfuamcdXp36Ez4JPdVn_H3IcBoRH82qySERBDTBlSDsk81sAq5lBy2XTeF7K6HmnUIXOqEkM8asJboVA4ov_jkiBHnnT1Sccozap4yJLnlDNwWvILwUR7qmrkNY2VFZLcYboEm3ZqEruqDhtpUxP12lFcCfTOuNus7BPOO5i2lE1eknA5v5gnyR4JbRQz3QTHy',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6251218, 'lng': -116.2123933},
#                            'viewport': {'northeast': {'lat': 43.62632297989272,
#                                                       'lng': -116.2111938701073},
#                                         'southwest': {'lat': 43.62362332010727,
#                                                       'lng': -116.2138935298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'North End Chinese Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3264,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102960671513587619713">Nicholas '
#                                                 'DiPietro</a>'],
#                           'photo_reference': 'Aap_uEDIEGYgjO0lfFzxge1ttmjyrqRI3FFDVNEFqdv6lQV2RmfzEBpHCMzxyAUG6v6elit8j3nSX8FiKqoOMvEX-FX6RKPxCxMocNbrxUtzHJD1Rk1f2cJ9Bj4dVOE_Kf7Wf8i0rYkoB3KWJCb6cO4AWN7_Dd3duMDQQZLMdJD-xeq8vu0_',
#                           'width': 2448}],
#               'place_id': 'ChIJP5lMQNz4rlQRPRigHmorMWw',
#               'plus_code': {'compound_code': 'JQGQ+22 Boise, Idaho',
#                             'global_code': '85M5JQGQ+22'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJP5lMQNz4rlQRPRigHmorMWw',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 239,
#               'vicinity': '1806 W State St #3955, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6487584, 'lng': -116.2461602},
#                            'viewport': {'northeast': {'lat': 43.65001942989272,
#                                                       'lng': -116.2449492201073},
#                                         'southwest': {'lat': 43.64731977010727,
#                                                       'lng': -116.2476488798928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'New Garden Chinese Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110284797720925008141">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'Aap_uECJTU6_0tWGlSh-DCufCp2FawXp686GzjNA3fLwPA_UuQs8zW95SpsQZfnzQiMN36LX98aL0o8dbYQJzz7vOov2hgMtnlh9L0Fvdd1clqgL0CRtdsx2DfTuT7At1SjYdZQD3kBpWyPgmb8Izy7ZcD4bp93gPn05GUDKtJQFnhso9NrZ',
#                           'width': 3120}],
#               'place_id': 'ChIJvwYXUDz_rlQRKpVyY618JMM',
#               'plus_code': {'compound_code': 'JQX3+GG Boise, Idaho',
#                             'global_code': '85M5JQX3+GG'},
#               'price_level': 1,
#               'rating': 3.9,
#               'reference': 'ChIJvwYXUDz_rlQRKpVyY618JMM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 161,
#               'vicinity': '4624 W State St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.5910063, 'lng': -116.2900003},
#                            'viewport': {'northeast': {'lat': 43.59235617989272,
#                                                       'lng': -116.2885996701073},
#                                         'southwest': {'lat': 43.58965652010728,
#                                                       'lng': -116.2912993298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Lucky Palace Chinese Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2534,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116258063497492904062">hyt5168</a>'],
#                           'photo_reference': 'Aap_uECYG5NUNw01h_8BCQyvkCFuX492VA-0RsnYDNd6l-fLnGbB4i4jKZwgsKLs6lk65q1eeusL8aPbdcmdW5F4N57OFXSYIAMT05dAqurTgjT91pswQR78DKbhVvrHDZYNV0WyNgSWnsYnIMtT1IdyATz1s55lmMNc8mGLG8YvI9FNtUtS',
#                           'width': 4032}],
#               'place_id': 'ChIJ5RKyTVZWrlQRY-t-LLVVQ9M',
#               'plus_code': {'compound_code': 'HPR5+CX Boise, Idaho',
#                             'global_code': '85M5HPR5+CX'},
#               'price_level': 2,
#               'rating': 3.9,
#               'reference': 'ChIJ5RKyTVZWrlQRY-t-LLVVQ9M',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 193,
#               'vicinity': '8630 W Overland Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6180738, 'lng': -116.2031764},
#                            'viewport': {'northeast': {'lat': 43.61938092989272,
#                                                       'lng': -116.2017260701073},
#                                         'southwest': {'lat': 43.61668127010728,
#                                                       'lng': -116.2044257298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Yen Ching Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108162030028686925379">Tye '
#                                                 'Lombardi</a>'],
#                           'photo_reference': 'Aap_uEBqlDaAZoOeMPzJkijiylETung0pT00uUf6_lmi-4-A3BQNiv0Cz0cOGsFCOEX1I-Re9wvJpYPRxmZmUI1Eq_cbwjJ4G1Nu8mk8J7K1VziuUnNs_bBodr-47cyg6LYHBJi4Gb4Z6IKsFIDRgBb4PN7FrAxvE_Mx5Pzn0NIH9lOu71HB',
#                           'width': 2268}],
#               'place_id': 'ChIJD1s29-P4rlQR0QVGxC9AWY0',
#               'plus_code': {'compound_code': 'JQ9W+6P Boise, Idaho',
#                             'global_code': '85M5JQ9W+6P'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJD1s29-P4rlQR0QVGxC9AWY0',
#               'scope': 'GOOGLE',
#               'types': ['bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 515,
#               'vicinity': '305 N 9th St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6200457, 'lng': -116.3128558},
#                            'viewport': {'northeast': {'lat': 43.62137212989272,
#                                                       'lng': -116.3116452201073},
#                                         'southwest': {'lat': 43.61867247010728,
#                                                       'lng': -116.3143448798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'China Grand Buffet',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113139047208396639642">Stephen '
#                                                 'Newcomb</a>'],
#                           'photo_reference': 'Aap_uEDsXdj77cbSafKGBxDhQcry3FZOa7Xa-gdv450K4tXZOTqNlEAEL-7z4Sep2di3oLIiv-uA-8eZiAkpcALlVeqXDmsXZddxw3i13GUfBXld4WTlYV0w5LcJbSM2BQpFe-5mH539hg0RuoE8QaJwHQu-oQ5H4c-xjAARbdzc3V50EJ9Z',
#                           'width': 4032}],
#               'place_id': 'ChIJTSFfGNRVrlQRuTYkj0zGqMM',
#               'plus_code': {'compound_code': 'JMCP+2V Boise, Idaho',
#                             'global_code': '85M5JMCP+2V'},
#               'price_level': 1,
#               'rating': 4.1,
#               'reference': 'ChIJTSFfGNRVrlQRuTYkj0zGqMM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2327,
#               'vicinity': '10498 W Fairview Ave, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6136713, 'lng': -116.2057373},
#                            'viewport': {'northeast': {'lat': 43.61494772989272,
#                                                       'lng': -116.2042832701073},
#                                         'southwest': {'lat': 43.61224807010728,
#                                                       'lng': -116.2069829298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': "P.F. Chang's",
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110915979167648784292">Cyrus '
#                                                 'Pintor</a>'],
#                           'photo_reference': 'Aap_uEByn1Yc2eY0v_dA30E4xxDTfH-miokhOYSmA01CgeipBd1TNU6xZdAPPApUEYzn4DQUvcbMmbx62EN2rR4WOqE5eUqC4joh1NJT2Kk9V9ZCYMJWpONCon-ov45IqqGxg3uvBtOb5tOxLljSuy9G3_qbdle7003KWQYrZudbhaekcTWl',
#                           'width': 4032}],
#               'place_id': 'ChIJEVx3TeX4rlQR4QkPYThohEg',
#               'plus_code': {'compound_code': 'JQ7V+FP Boise, Idaho',
#                             'global_code': '85M5JQ7V+FP'},
#               'price_level': 2,
#               'rating': 4.2,
#               'reference': 'ChIJEVx3TeX4rlQR4QkPYThohEg',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1381,
#               'vicinity': '391 S 8th St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6149025, 'lng': -116.2427673},
#                            'viewport': {'northeast': {'lat': 43.61625252989272,
#                                                       'lng': -116.2415218701072},
#                                         'southwest': {'lat': 43.61355287010727,
#                                                       'lng': -116.2442215298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Golden Star Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112010777321852232295">Raquel '
#                                                 'Perez</a>'],
#                           'photo_reference': 'Aap_uEBMBRE55eV7JGr_06CTsx7cgq5xLs4A7IrWWigWjCBlii1Afo42glb-7DoY8Rp2rnJc7pJGId9lgPkcJ-OMo3CeqCnI3RXHHx8uTkB5UAG1SjXozdhBT8pH-ErmJYjJYwJs4iPkLDdtc88EO2h0zTwh9_MF_a2B_gpYCUjVc9bZ1Mrh',
#                           'width': 3456}],
#               'place_id': 'ChIJTctsXaL4rlQRbC1U996y4-0',
#               'plus_code': {'compound_code': 'JQ74+XV Boise, Idaho',
#                             'global_code': '85M5JQ74+XV'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJTctsXaL4rlQRbC1U996y4-0',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 839,
#               'vicinity': '1142 N Orchard St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.5888893, 'lng': -116.2776039},
#                            'viewport': {'northeast': {'lat': 43.59032242989273,
#                                                       'lng': -116.2762745201073},
#                                         'southwest': {'lat': 43.58762277010728,
#                                                       'lng': -116.2789741798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Guang Zhou Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101811418303658757333">Alex '
#                                                 'Inskeep</a>'],
#                           'photo_reference': 'Aap_uEDwKHj2BlTvY3FaTAbk8Wo9fPRnvVwn_LQD0-hmkh6GeOZm-DEhggf3OAcTeRHv0eOHm1EpsgmVZIc-qUu4nfKo6pn_1-RWOYjuFswCxmPGE97ykwfKzNeAO9lOXbM1J57JSSChIOJ8Yk6Qq0x5-6xQoqsNbAomfL4oOJWuZ3gePWqv',
#                           'width': 4032}],
#               'place_id': 'ChIJDT-7DlJWrlQRO7rtBTzZf6s',
#               'plus_code': {'compound_code': 'HPQC+HX Boise, Idaho',
#                             'global_code': '85M5HPQC+HX'},
#               'price_level': 1,
#               'rating': 4.1,
#               'reference': 'ChIJDT-7DlJWrlQRO7rtBTzZf6s',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 431,
#               'vicinity': '7609 W Overland Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.62829869999999,
#                                         'lng': -116.2467501},
#                            'viewport': {'northeast': {'lat': 43.62964852989272,
#                                                       'lng': -116.2454002701073},
#                                         'southwest': {'lat': 43.62694887010727,
#                                                       'lng': -116.2480999298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Golden Wok',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108564864349711743478">Trang '
#                                                 'Pham</a>'],
#                           'photo_reference': 'Aap_uEBnBb7SPk0UL5GfLq0sRvYArGApukeY0E93V-_QRlSTIVx0YdwylmU4i2NVptr9HUTxfPyaGbTEOxif6JXXjKxaGTkpy3EwFfjfDM5MZ7lpAStFbHey8D-6BtYlrxd9SdoqxqYomwHIuXQVF0MEnzXzd6xrXTKtaR4r2aCcnXycXE_a',
#                           'width': 3024}],
#               'place_id': 'ChIJ4-wGxrP4rlQRQBpLRX5r_t0',
#               'plus_code': {'compound_code': 'JQH3+87 Boise, Idaho',
#                             'global_code': '85M5JQH3+87'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJ4-wGxrP4rlQRQBpLRX5r_t0',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 440,
#               'vicinity': '3948 W Chinden Blvd #6412, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6029245, 'lng': -116.2444675},
#                            'viewport': {'northeast': {'lat': 43.60422497989273,
#                                                       'lng': -116.2431192701073},
#                                         'southwest': {'lat': 43.60152532010729,
#                                                       'lng': -116.2458189298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Mandarin Palace',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2274,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103311480146692398200">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'Aap_uEA6sfWX6iedofKKqHQwkLJehXd8IPNjQYGI1FRwojjNnoMBYivzaNRp9xmJhxepKyL5nk2K_ZvztADRP4Pz_RXu-rnF_Z-jZodqBJaWDqAOX2z-IR_LFV_KwS0vFqJAJ-qjRzyvUmVxCs9OSE2oE84PwtWc50CTsniBxgdrEB-CS4MN',
#                           'width': 3095}],
#               'place_id': 'ChIJecwebShWrlQRo_MtO2S0rdA',
#               'plus_code': {'compound_code': 'JQ34+56 Boise, Idaho',
#                             'global_code': '85M5JQ34+56'},
#               'price_level': 1,
#               'rating': 3.7,
#               'reference': 'ChIJecwebShWrlQRo_MtO2S0rdA',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 262,
#               'vicinity': '5020 W. Franklin St., Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6128764, 'lng': -116.2031451},
#                            'viewport': {'northeast': {'lat': 43.61424682989271,
#                                                       'lng': -116.2016703201073},
#                                         'southwest': {'lat': 43.61154717010727,
#                                                       'lng': -116.2043699798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Express',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3036,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117353903133578767077">James '
#                                                 'Derderian</a>'],
#                           'photo_reference': 'Aap_uEBqQhsrWCkn9Y3-MIFtA9l4bKKEzRKMGFnN1-psTXkvzfVYQP49jb_emfUoJ0goT6xRY-NlNO5HPlAzdKV0tSjTYs-yuo241xSvd7NwCG2RmMbZqNPVr3Gg473iDP0yTSjKI726Lp2Z7hd5UryXNW80zUblUAkGzcmpB3GKlHMptsuf',
#                           'width': 4048}],
#               'place_id': 'ChIJkevL-_r4rlQRdCX2O8ZXDsM',
#               'plus_code': {'compound_code': 'JQ7W+5P Boise, Idaho',
#                             'global_code': '85M5JQ7W+5P'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJkevL-_r4rlQRdCX2O8ZXDsM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 237,
#               'vicinity': '601 W Front St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.5906484, 'lng': -116.2801612},
#                            'viewport': {'northeast': {'lat': 43.59196002989272,
#                                                       'lng': -116.2788730701073},
#                                         'southwest': {'lat': 43.58926037010728,
#                                                       'lng': -116.2815727298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Express',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 282,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109235819106383651889">中野竜</a>'],
#                           'photo_reference': 'Aap_uED7vV9sOYxqVQ4i0svy2qPkeNMQMlXFjhD3BDPZ3Hyy9NmUmSjxief9rgLD3W10A9fEMIxIPh4Eyfk94a4CRLet1TPc9_AS1mKVvT6PWAJoX1fLBrupzA7JmyO4yNYhZQtPTtVXslJyu_hrfQC-frDJrZbEpkWzeoyU7hii_AGldoAu',
#                           'width': 448}],
#               'place_id': 'ChIJb15nIlJWrlQRcvGGNq_0WC8',
#               'plus_code': {'compound_code': 'HPR9+7W Boise, Idaho',
#                             'global_code': '85M5HPR9+7W'},
#               'price_level': 1,
#               'rating': 4.1,
#               'reference': 'ChIJb15nIlJWrlQRcvGGNq_0WC8',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1042,
#               'vicinity': '7804 W Overland Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.577295, 'lng': -116.195009},
#                            'viewport': {'northeast': {'lat': 43.57901292989273,
#                                                       'lng': -116.1936632701073},
#                                         'southwest': {'lat': 43.57631327010728,
#                                                       'lng': -116.1963629298928}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Season Wok',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1208,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117474966032883412922">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'Aap_uED0D7CcbSEtaXRStYNDxtsSv82TTnZWqPcfhYCIQrHKTw62J2s49h181WC9Afp1enCEj3nijqB4GqqCeOvCozQrW2LQDLLaHb2UHiE8TXHdtzzMgYA0C7VEk9lRqg5GSh3JpQH3UJtdRJO1KG0QUtklH9nfFf7F3H_aQBYD0ofgwKbx',
#                           'width': 1074}],
#               'place_id': 'ChIJ_9TdpxD4rlQRdg8ROoJbNSw',
#               'plus_code': {'compound_code': 'HRG3+WX Boise, Idaho',
#                             'global_code': '85M5HRG3+WX'},
#               'price_level': 1,
#               'rating': 3.5,
#               'reference': 'ChIJ_9TdpxD4rlQRdg8ROoJbNSw',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 157,
#               'vicinity': '2775 Broadway Ave, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.589956, 'lng': -116.241835},
#                            'viewport': {'northeast': {'lat': 43.59120952989272,
#                                                       'lng': -116.2405126701073},
#                                         'southwest': {'lat': 43.58850987010727,
#                                                       'lng': -116.2432123298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Quik-Wok Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2448,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104596854037149095654">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'Aap_uEDKTqNWd4nyQTtk0dVj5cN42lixsj6UmBwCaKgYtsVDZ1bIl0bMWaNsOItgQt2s4LOmltwaSFRhOSvbaKjpiXEyGzCUfvTOF14ZPulwEiQs_aYo_wdBq4pOQvIKKY3FNJyRpE_M5GbUzisZrcnXvDfuorzYSVLgGnO4lf2Kk-X7hjOF',
#                           'width': 3264}],
#               'place_id': 'ChIJbRshL9JXrlQRDa61aB-RK2E',
#               'plus_code': {'compound_code': 'HQQ5+X7 Boise, Idaho',
#                             'global_code': '85M5HQQ5+X7'},
#               'price_level': 2,
#               'rating': 3.5,
#               'reference': 'ChIJbRshL9JXrlQRDa61aB-RK2E',
#               'scope': 'GOOGLE',
#               'types': ['meal_delivery',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 406,
#               'vicinity': '4858 W Overland Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.614921, 'lng': -116.2838702},
#                            'viewport': {'northeast': {'lat': 43.61626807989271,
#                                                       'lng': -116.2823547201073},
#                                         'southwest': {'lat': 43.61356842010727,
#                                                       'lng': -116.2850543798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Express',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118350779690464862712">Roxana '
#                                                 'Curtis</a>'],
#                           'photo_reference': 'Aap_uECzZbbwx_cBn9qH_ftl2lK7oL-GPCzg7zxydTAPPh5Av9BNyty9pfZEd6aUfdoxAm0WeKbi00_Ev7vGBqXbsxGLfVorWhxZqOTbCVGK7dwmksPERYvUv-1H_gBsGshCQEL11RILjsaBpftcgbPMMwf9qzUzgqn3eVmZPrEZl-zHhgXO',
#                           'width': 4032}],
#               'place_id': 'ChIJbdZEMQ1WrlQRcVfVf-Hl8g8',
#               'plus_code': {'compound_code': 'JP78+XF Boise, Idaho',
#                             'global_code': '85M5JP78+XF'},
#               'price_level': 1,
#               'rating': 4,
#               'reference': 'ChIJbdZEMQ1WrlQRcVfVf-Hl8g8',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 440,
#               'vicinity': '1124 N Milwaukee St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6653862, 'lng': -116.2801056},
#                            'viewport': {'northeast': {'lat': 43.66673117989272,
#                                                       'lng': -116.2785765701072},
#                                         'southwest': {'lat': 43.66403152010727,
#                                                       'lng': -116.2812762298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Express',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2048,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100777468694236261816">Tessie '
#                                                 'Page</a>'],
#                           'photo_reference': 'Aap_uEAinufdkW6QBe8ecHKa3qPnLWqqDsHUaOnHo5sAbA_7DzhoxDoLrZTtxUbIbPPiklbWLdkZRrKtHIYGSj_Jsn9qzr6cu0Zsj5YDt7MwyKyRIp9hxjf6QYZoVZgXIVPwB1bvcNa6Yq-jmzsgk21lY6jlApwJ5ybEvycIrj1ozt56LYPl',
#                           'width': 1536}],
#               'place_id': 'ChIJLdWyiJ7_rlQRIRdU-1NWqEw',
#               'plus_code': {'compound_code': 'MP89+5X Garden City, Idaho',
#                             'global_code': '85M5MP89+5X'},
#               'price_level': 1,
#               'rating': 4.1,
#               'reference': 'ChIJLdWyiJ7_rlQRIRdU-1NWqEw',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 496,
#               'vicinity': '6675 N Glenwood St, Garden City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.6123556, 'lng': -116.2430374},
#                            'viewport': {'northeast': {'lat': 43.61360837989272,
#                                                       'lng': -116.2416783201072},
#                                         'southwest': {'lat': 43.61090872010728,
#                                                       'lng': -116.2443779798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Wok-Inn Noodle',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2327,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115594850829248502065">Matthew '
#                                                 'Reed</a>'],
#                           'photo_reference': 'Aap_uEAshQ0sQ-cUFGjmAaFa3SwdEqCxVDIHgf7azo0eqAAZEQCLgSi0o7NskBSIlvArzpx8f7d1Nu3pTDICL6Bgu_qPo-15dRsCuA_mycBicPBzuUTXTbNHf7VfjKDx9Rtrbvr0a_vG6I1Uu46JH1ubltRiL2eVR9vnbMEFoz6N-0iYMgwx',
#                           'width': 2149}],
#               'place_id': 'ChIJe9STjx9WrlQRnMGkKZFN9V4',
#               'plus_code': {'compound_code': 'JQ64+WQ Boise, Idaho',
#                             'global_code': '85M5JQ64+WQ'},
#               'price_level': 1,
#               'rating': 4.4,
#               'reference': 'ChIJe9STjx9WrlQRnMGkKZFN9V4',
#               'scope': 'GOOGLE',
#               'types': ['meal_takeaway',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 269,
#               'vicinity': '4912 Emerald St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.60734859999999,
#                                         'lng': -116.2787673},
#                            'viewport': {'northeast': {'lat': 43.60870507989272,
#                                                       'lng': -116.2776810201073},
#                                         'southwest': {'lat': 43.60600542010727,
#                                                       'lng': -116.2803806798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Express',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104961771114871630072">Bobbie '
#                                                 'Owen</a>'],
#                           'photo_reference': 'Aap_uEBmj8kNehaOHhHHogLKPyejFjR9jGc1elkzOytLMj0KKV4-zsTOOkicwa25onwSHFWIV0NQgNED0Oouq85TL8zg8oGJvh4V_D1OYLRLetyri7hY4IslQmdsg_UPo4wCR4iuq1OwEspU3P4amZ_xu5c_P34yqWx9uYdZz1oP6drTCA-W',
#                           'width': 3024}],
#               'place_id': 'ChIJfYBLkWpWrlQRjig0x7oVFfk',
#               'plus_code': {'compound_code': 'JP4C+WF Boise, Idaho',
#                             'global_code': '85M5JP4C+WF'},
#               'price_level': 1,
#               'rating': 3.3,
#               'reference': 'ChIJfYBLkWpWrlQRjig0x7oVFfk',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 118,
#               'vicinity': '350 N Milwaukee St, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.58963800000001,
#                                         'lng': -116.216586},
#                            'viewport': {'northeast': {'lat': 43.59101702989273,
#                                                       'lng': -116.2151431201073},
#                                         'southwest': {'lat': 43.58831737010728,
#                                                       'lng': -116.2178427798927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Panda Garden',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104209746584677475752">Craig '
#                                                 'Lowary</a>'],
#                           'photo_reference': 'Aap_uEAS0n5k6exAGXO2IlEqQP_GQ6nlSNec_qVKZptE-ZC7Ncmag2qgZzA5Vb41GBULOBMLBE38uKPhhtj49s2u6WRt19Df5QiiHONVjG9ujtBcvozW7OEm0rZng_K-pZJChes7LGr7W3_4z1RAQpwWr-q9SKTIG9pljU10OVY3LHshAU_I',
#                           'width': 4032}],
#               'place_id': 'ChIJ2VoTQ3D4rlQR3UKIMJlQFeI',
#               'plus_code': {'compound_code': 'HQQM+V9 Boise, Idaho',
#                             'global_code': '85M5HQQM+V9'},
#               'price_level': 1,
#               'rating': 3.9,
#               'reference': 'ChIJ2VoTQ3D4rlQR3UKIMJlQFeI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 377,
#               'vicinity': '2801 W Overland Rd, Boise'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 43.5915577, 'lng': -116.3116912},
#                            'viewport': {'northeast': {'lat': 43.59287852989272,
#                                                       'lng': -116.3105545701073},
#                                         'southwest': {'lat': 43.59017887010728,
#                                                       'lng': -116.3132542298927}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Great Wall Restaurant',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1152,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109235819106383651889">RYU</a>'],
#                           'photo_reference': 'Aap_uEDSQQPItmJJOPosyaewsP7hRMFbsh87vdUB5_DDi8oGWqTtDSZqPx_MeYo7rrDK0iVuUN77BUJZ0J8gxMdQXUeZjlQOaMFAw2Ii4gac6mIl59e-C_rzIKElbK0NpesV7W20LnMVwm7n0-VpONaxO1g4jaS4yhQZPoESemeGwdDYuOxH',
#                           'width': 2048}],
#               'place_id': 'ChIJle9LyO5WrlQRyBqJqPmCLQI',
#               'plus_code': {'compound_code': 'HMRQ+J8 Boise, Idaho',
#                             'global_code': '85M5HMRQ+J8'},
#               'price_level': 1,
#               'rating': 3.9,
#               'reference': 'ChIJle9LyO5WrlQRyBqJqPmCLQI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 747,
#               'vicinity': '10398 W Overland Rd, Boise'}],
#  'status': 'OK'}

# %%
# Print the name and address of the first restaurant that appears
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# North End Chinese Restaurant
# 1806 W State St #3955, Boise

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import pandas as pd
import plotly.express as px
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

# %%
result = load_iris()

# %%
feature_names = result["feature_names"]

# %%
X = result["data"]

# %%
k_means = KMeans(n_clusters=NUM_MEANS)

# %%
k_means.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
labels = k_means.labels_

# %%
vizualizer = KElbowVisualizer(KMeans(), k=(1, 10))
vizualizer.fit(X)
vizualizer.show()

# %%
vizualizer = KElbowVisualizer(KMeans(), k=(2, 10), metric="silhouette")
vizualizer.fit(X)
vizualizer.show()

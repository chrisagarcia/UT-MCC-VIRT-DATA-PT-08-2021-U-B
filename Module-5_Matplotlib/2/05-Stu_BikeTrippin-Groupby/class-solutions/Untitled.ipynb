# %%
import pandas as pd

# %%
df = pd.read_csv("../Unsolved/Resources/trip.csv")[lambda df: df["gender"] != "stoptime"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286857 entries, 0 to 286857
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   stoptime           286857 non-null  object
#  1   bikeid             286857 non-null  object
#  2   tripduration       286857 non-null  float64
#  3   from_station_name  286857 non-null  object
#  4   to_station_name    286857 non-null  object
#  5   from_station_id    286857 non-null  object
#  6   to_station_id      286857 non-null  object
#  7   usertype           286857 non-null  object
#  8   gender             181557 non-null  object
#  9   birthyear          181553 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 24.1+ MB

# %%
df["gender"].fillna("Unknown").value_counts().plot.bar()

# %%
df.fillna("Unknown").groupby("gender")["gender"].count().sort_values(ascending=False).plot.bar()

# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/used_cars.csv")

# %%
df.value_counts("maker").plot.bar()

# %%
df.groupby("maker")["mileage"].mean().sort_values(ascending=False).plot.bar()
